# %%
pip install --q deeppavlov
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'd:\DeepPavlov_TestLab\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !python -m deeppavlov install squad_bert
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'd:\DeepPavlov_TestLab\env\Scripts\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'd:\DeepPavlov_TestLab\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from deeppavlov import build_model

model = build_model('squad_bert', download=True)
# Out:
# 2022-11-18 22:47:46.384 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/v1/squad/squad_torch_bert_cased.tar.gz download because of matching hashes
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\79126\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\79126\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\79126\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     C:\Users\79126\AppData\Roaming\nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# ...

# %%
model(['DeepPavlov is a library for NLP and dialog systems.'], ['What is DeepPavlov?'])
# Out:
# [['a library for NLP and dialog systems'], [14], [1.0]]

# %%
model(['A military conflict involving 38 States between two coalitions of states in Europe, the fighting of which has also spread to the Middle East, Africa and parts of Asia'], ['How many States participated in the conflict?'])
# Out:
# [['38'], [30], [1.0]]

# %%
model(['A military conflict involving 38 States between two coalitions of states in Europe, the fighting of which has also spread to the Middle East, Africa and parts of Asia'], ['Whose fighting has spread to?'])
# Out:
# [['Middle East, Africa and parts of Asia'], [129], [1.0]]

# %%
model(['A military conflict involving 38 States between two coalitions of states in Europe, the fighting of which has also spread to the Middle East, Africa and parts of Asia'], ['What was the conflict?'])
# Out:
# [['A military conflict involving 38 States between two coalitions of states in Europe'],
#  [0],
#  [1.0]]
